# %%
# CELL 1 — Imports
# We only need math (for exp) and pandas (to display a nice table).
import math
import pandas as pd

# %%
# CELL 2 — Enter your regression results
# beta = coefficient on the log-odds scale
# se   = standard error of beta
# p_value is kept as text since some are shown as "<0.001"

results = pd.DataFrame([
    {"Variable": "Intercept",              "beta": -2.10, "se": 0.40, "p_value": "<0.001"},
    {"Variable": "Biologic (vs Standard)", "beta":  0.58, "se": 0.22, "p_value": "0.009"},
    {"Variable": "Age (per 10 yrs)",       "beta":  0.35, "se": 0.08, "p_value": "<0.001"},
    {"Variable": "Diabetes (Yes)",         "beta":  0.72, "se": 0.25, "p_value": "0.004"},
])

results
# Out:
#                  Variable  beta    se p_value
# 0               Intercept -2.10  0.40  <0.001
# 1  Biologic (vs Standard)  0.58  0.22   0.009
# 2        Age (per 10 yrs)  0.35  0.08  <0.001
# 3          Diabetes (Yes)  0.72  0.25   0.004
